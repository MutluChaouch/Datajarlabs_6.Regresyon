# %% [markdown]
# ## 6.5. Modelin Egitim Performansini Olcme - Odev2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

baslik_font = {'family': 'arial','color':  'darkred','weight': 'bold','size': 15 }
eksen_font = {'family': 'arial','color':  'darkblue','weight': 'bold','size': 10 }

# %%
# İlk olarak, Sıcaklık verilerini Kaggle'dan indirin.

sicaklik = pd.read_csv('weatherHistory.csv')
sicaklik.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain            9.472
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain            9.356
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain            9.378
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain            8.289
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain            8.756
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     7.389     0.890             14.120
# 1                     7.228     0.860             14.265
# 2                     9.378     0.890              3.928
# 3                     5.944     0.830             14.104
# 4                     6.978     0.830             11.045
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                 251.000           15.826       0.000              1015.130
# ...

# %%
# Önceki derste olduğu gibi, hedef değişkeninizin görünür sıcaklık ve sıcaklık arasındaki fark olduğu bir doğrusal 
# regresyon modeli oluşturun. Açıklayıcı değişkenler olarak nem ve rüzgar hızı kullanın. 

sicaklik['Temp_fark']=sicaklik["Apparent Temperature (C)"]-sicaklik["Temperature (C)"]
Y = sicaklik['Temp_fark']
X = sicaklik[['Humidity',"Wind Speed (km/h)"]]

# %%
# Şimdi, modelinizi OLS kullanarak tahmin edin. R-kare ve ayarlanmış R-kare değerleri nelerdir? 
# Tatminkar olduklarını düşünüyor musunuz? Açıklayın

X = sm.add_constant(X)
results = sm.OLS(Y,X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Temp_fark   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Sat, 06 Mar 2021   Prob (F-statistic):               0.00
# Time:                        15:32:04   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# R-kare ve ayarlanmis R-kare degerleri 0.288'dir. Cok dusuk olduklari icin aciklayici olduklarini dusunmuyorum.

# %%
# Daha sonra, yukarıdaki modele nem ve rüzgar hızı etkileşimini dahil edin ve OLS'yi kullanarak modeli tahmin edin.
# Şimdi, bu modelin R-kare değeri nedir? Bu model bir öncekine göre gelişti mi?

Y = sicaklik['Temp_fark']
sicaklik ['humidity_windspeed'] = sicaklik['Humidity']*sicaklik['Wind Speed (km/h)']
X = sicaklik[['Humidity',"Wind Speed (km/h)",'humidity_windspeed']]

X = sm.add_constant(X)

sonuclar = sm.OLS(Y,X).fit()
sonuclar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Temp_fark   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Sat, 06 Mar 2021   Prob (F-statistic):               0.00
# Time:                        15:34:06   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# R-kare ve ayarlanmis R-kare degerleri 0.341'dir. Bu model bir oncekine gore daha aciklayici olmasina ragmen, 
# halen daha R-kare degerinin dusuk oldugunu dusunuyorum.

# %%
# İlk modele ek açıklayıcı değişken olarak görünürlük ekleyin ve tahmin edin. R-kare arttı mı? 
# Ayarlanmış R-kare değeri ne oldu? Tabloda ortaya çıkan farklılıkları, ayarlanmış R-kare içindeki iyileşme 
# açısından etkileşim terimi ve görünürlük ile karşılaştırın. Hangisi daha kullanışlı?

Y = sicaklik['Temp_fark']
X = sicaklik[['Humidity','Wind Speed (km/h)','Visibility (km)']]
X = sm.add_constant(X)
results = sm.OLS(Y,X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Temp_fark   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                 1.401e+04
# Date:                Sat, 06 Mar 2021   Prob (F-statistic):               0.00
# Time:                        15:37:17   Log-Likelihood:            -1.6938e+05
# No. Observations:               96453   AIC:                         3.388e+05
# Df Residuals:                   96449   BIC:                         3.388e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# AIC ve BIC puanlarına göre yukarıdaki üç modelden en iyisini seçin. Mentor ile gerekçenizi tartışarak seçiminizi 
# doğrulayın.

# 1. model:
R-kare: 0.288
Ayarlanmis R-kare: 0.288
F-statistics: 19490
AIC: 340900
BIC: 340900

# 2. model: 
R-kare: 0.341
Ayarlanmis R-kare: 0.341
F-statistics: 16660
AIC: 333400
BIC: 333400

# 3. model:
R-kare: 0.304
Ayarlanmis R-kare: 0.303
F-statistics: 14010
AIC: 338800
BIC: 338800
    
# Yukaridaki 3 modele baktigimzida hem R-kare ve Ayarlanmis R-kare degerlerine hem de AIC ve BIC degerlerine gore
# 2. model en iyi secim gibi duruyor. Ancak F-stat degeri 1. modelden daha dusuk. Buna bakilabilir
